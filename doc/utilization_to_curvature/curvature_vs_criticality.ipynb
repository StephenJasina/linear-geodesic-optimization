# %%
import itertools
import pathlib
import sys

import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

sys.path.append(str(pathlib.PurePath('..', '..', 'src')))
from linear_geodesic_optimization.data import input_network, tomography
from linear_geodesic_optimization import plot

# %%
path_probes = pathlib.PurePath('probes.csv')
path_links = pathlib.PurePath('links.csv')
graph = input_network.get_graph_from_csvs(
    path_probes, path_links,
    clustering_distance=500000,
    should_compute_curvatures=False,
    directed=True,
    symmetrize=True
)

routes = tomography.get_shortest_routes(graph, 'gcl')
traffic = tomography.compute_traffic(graph, routes, 'throughput')
traffic_dict = {(route[0], route[-1]): t for route, t in zip(routes, traffic)}

# %%
graph = input_network.compute_ricci_curvatures(
    graph, weight_label='throughput',
    routes=routes, traffic=traffic
)

fig, ax = plt.subplots(1, 1, facecolor='#808080')
fig.set_dpi(200)
plot.get_network_plot(graph, ax=ax)
plt.show()

# %%
# Compute shortest path lengths of actual routes
lengths = {}
for route in routes:
    source, destination = route[0], route[-1]
    length = 0.
    for u, v in itertools.pairwise(route):
        length += graph.edges[u, v]['gcl']
    lengths[source, destination] = length

# %%
# For each route, remove each link and check how it influences the
# route's length
lengths_with_removals = {}
for route in routes:
    source, destination = route[0], route[-1]
    lengths_with_removals_source_destination = {}

    for u, v in itertools.pairwise(route):
        # Remove the link
        u_v_data = graph.edges[u, v]
        graph.remove_edge(u, v)

        # Compute the shortest path length
        lengths_with_removals_source_destination[u, v] \
            = nx.shortest_path_length(graph, u, v, 'gcl')

        # Restore the link
        graph.add_edge(u, v, **u_v_data)

    lengths_with_removals[source, destination] \
        = lengths_with_removals_source_destination

# %%
x = np.array([
    graph.edges[u, v]['ricciCurvature']
    for (source, destination), lengths_with_removals_source_destination in lengths_with_removals.items()
    for (u, v) in lengths_with_removals_source_destination
])
y = np.array([
    length_with_removal / lengths[source, destination]
    for (source, destination), lengths_with_removals_source_destination in lengths_with_removals.items()
    for (u, v), length_with_removal in lengths_with_removals_source_destination.items()
])
colormap = mpl.colormaps['RdBu']
traffic_max = max(traffic_dict.values())
colors = np.array([
    colormap(traffic_dict[source, destination] / traffic_max)
    for (source, destination), lengths_with_removals_source_destination in lengths_with_removals.items()
    for (u, v) in lengths_with_removals_source_destination
])
order = [
    index
    for _, index in sorted(
        zip(
            [
                traffic_dict[source, destination]
                for (source, destination), lengths_with_removals_source_destination in lengths_with_removals.items()
                for (u, v) in lengths_with_removals_source_destination
            ],
            itertools.count()
        )
    )
]

fig, ax = plt.subplots(1, 1, dpi=150)
ax_scatter = ax.scatter(x[order], y[order], c=colors[order])
fig.colorbar(ax_scatter, label='Traffic on Route')
ax.set_xlabel('Ricci Curvature')
ax.set_ylabel('Relative Change in Route Length')
plt.show()

# %%
lengths_with_removals_transpose = {}
for (u, v) in graph.edges:
    lengths_with_removals_transpose[u, v] = {}
for (source, destination), lengths_with_removals_source_destination in lengths_with_removals.items():
    for (u, v), length_with_removal in lengths_with_removals_source_destination.items():
        lengths_with_removals_transpose[u, v][source, destination] = length_with_removal

traffic_edges = {
    (u, v): 0.
    for (u, v) in graph.edges
}
for route, t in zip(routes, traffic):
    source, destination = route[0], route[-1]
    for u, v in itertools.pairwise(route):
        traffic_edges[u, v] += t

x = np.array([
    graph.edges[u, v]['ricciCurvature']
    for (u, v), traffic_u_v in traffic_edges.items()
    if traffic_u_v != 0.
])
y_median = np.array([
    np.quantile(
        [
            length_with_removal / lengths[source, destination]
            for (source, destination), length_with_removal in lengths_with_removals_transpose[u, v].items()
        ],
        0.5,
        method='inverted_cdf',
        weights=[
            traffic_dict[source, destination]
            for (source, destination) in lengths_with_removals_transpose[u, v]
        ]
    )
    for (u, v), traffic_u_v in traffic_edges.items()
    if traffic_u_v != 0.
])
y_max = np.array([
    np.quantile(
        [
            length_with_removal / lengths[source, destination]
            for (source, destination), length_with_removal in lengths_with_removals_transpose[u, v].items()
        ],
        1.,
        method='inverted_cdf',
        weights=[
            traffic_dict[source, destination]
            for (source, destination) in lengths_with_removals_transpose[u, v]
        ]
    )
    for (u, v), traffic_u_v in traffic_edges.items()
    if traffic_u_v != 0.
])
fig, ax = plt.subplots(1, 1, dpi=150)
ax.scatter(x, y_median, alpha=0.5, color='tab:blue', label='Median Distortion')
ax.scatter(x, y_max, alpha=0.5, color='tab:orange', label='Maximum Distortion')
ax.legend()
plt.show()
