# %% [markdown]
# First, some imports

# %%
import itertools
import pathlib
import sys

import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

sys.path.append(str(pathlib.PurePath('..', '..', 'src')))
from linear_geodesic_optimization.data import input_network, tomography
from linear_geodesic_optimization import plot

# %% [markdown]
# Now we make the network graph and compute Ollivier-Ricci curvatures. We ultimately want to compare these curvatures to other centrality measurements, so they will comprise the $x$-values in our scatter plots.

# %%
path_probes = pathlib.PurePath('probes.csv')
path_links = pathlib.PurePath('links.csv')
graph = input_network.get_graph_from_csvs(
    path_probes, path_links,
    clustering_distance=500000,
    should_compute_curvatures=False,
    directed=True,
    symmetrize=True
)

routes = tomography.get_shortest_routes(graph, 'gcl')
od_pairs = [(route[0], route[-1]) for route in routes]
traffic = tomography.compute_traffic(graph, routes, 'throughput')
traffic_matrix = {}
for route, traffic_route in zip(routes, traffic):
    if (route[0], route[-1]) not in traffic_matrix:
        traffic_matrix[route[0], route[-1]] = 0.
    traffic_matrix[route[0], route[-1]] += traffic_route

graph = input_network.compute_ricci_curvatures(
    graph, weight_label='throughput',
    routes=routes, traffic=traffic
)
ricci_curvatures = [
    data['ricciCurvature']
    for _, _, data in graph.edges(data=True)
]

# %% [markdown]
# Lets start by just plotting the network. The coloration of the edges will be the curvature values (red is negative, blue is positive).

# %%
fig, ax = plt.subplots(1, 1, facecolor='#808080')
fig.set_dpi(200)
plot.get_network_plot(graph, ax=ax)
plt.show()

# %% [markdown]
# Let's look at how removing an edge affects the average shortest path length (weighted by traffic). Clearly, the change will always increase when an edge is removed. We intuit that a negative curvature should indicate criticality of an edge, and therefore will cause a greater increase in average shortest path length.

# %%
# Compute shortest path lengths of actual routes
def compute_route_length(graph, route):
    length = 0.
    for u, v in itertools.pairwise(route):
        length += graph.edges[u, v]['gcl']
    return length

def compute_average_route_length(graph, traffic, od_pairs):
    traffic_total = sum(traffic)
    routes = tomography.get_shortest_routes(graph, 'gcl', od_pairs)
    return sum(
        traffic_route * compute_route_length(graph, route)
        for traffic_route, route in zip(traffic, routes)
    ) / traffic_total

# %%
# For each edge, compute the change in average route length
average_route_length_original = compute_average_route_length(graph, traffic, od_pairs)
length_changes = []
graph_copy = graph.copy()
for u, v in graph.edges:
    graph_copy.remove_edge(u, v)

    length_changes.append(
        compute_average_route_length(graph_copy, traffic, od_pairs)
            - average_route_length_original
    )

    graph_copy.add_edge(u, v, **graph.edges[u, v])

# %%
# Plot the change in path length vs. Ricci curvature
x = ricci_curvatures
y = length_changes
fig, ax = plt.subplots(1, 1, dpi=100)
ax_scatter = ax.scatter(x, y)
ax.set_xlabel('Ricci Curvature')
ax.set_ylabel('Average Change in Route Length')
plt.show()
